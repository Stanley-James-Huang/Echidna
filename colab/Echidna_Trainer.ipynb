# %%
# %tensorflow_version 1.x
# !pip install gpt_2_simple -t . --no-deps --upgrade
# !pip install toposort
import gpt_2_simple as gpt2
from google.colab import drive
# Out:
# TensorFlow 1.x selected.
# Collecting gpt_2_simple
#   Downloading https://files.pythonhosted.org/packages/e8/c9/44fe420225244ab9e3f2938a1d11651681078cf72f7444c66d0ea49f1320/gpt_2_simple-0.7.2.tar.gz
# Building wheels for collected packages: gpt-2-simple
#   Building wheel for gpt-2-simple (setup.py) ... done
#   Created wheel for gpt-2-simple: filename=gpt_2_simple-0.7.2-cp37-none-any.whl size=23621 sha256=6eaa1df2d4a8240cce769bd9ad311218668dbb23965d8ce0e8c1aeb345059d9d
#   Stored in directory: /root/.cache/pip/wheels/68/1d/15/c87a4302a6c7273ce1b4f282bec3c6877fb2f521535d87d30f
# Successfully built gpt-2-simple
# Installing collected packages: gpt-2-simple
# Successfully installed gpt-2-simple-0.7.2
# Collecting toposort
#   Downloading https://files.pythonhosted.org/packages/f2/7d/55784e894ee0cde2474fb977ffd1651e74e840a9f92e1d847f7e3115d5ec/toposort-1.6-py2.py3-none-any.whl
# Installing collected packages: toposort
# Successfully installed toposort-1.6
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
# !cp /content/drive/MyDrive/Echidna/gpt_2_simple/gpt_2.py /content/gpt_2_simple/gpt_2.py
# Out:
# cp: cannot stat '/content/drive/MyDrive/Echidna/gpt_2_simple/gpt_2.py': No such file or directory

# %%
model_name = "355M"
gpt2.download_gpt2(model_name=model_name)
# Out:
# Fetching checkpoint: 1.05Mit [00:00, 285Mit/s]
# Fetching encoder.json: 1.05Mit [00:00, 3.98Mit/s]
# Fetching hparams.json: 1.05Mit [00:00, 341Mit/s]
# Fetching model.ckpt.data-00000-of-00001: 1.42Git [00:37, 37.9Mit/s]
# Fetching model.ckpt.index: 1.05Mit [00:00, 546Mit/s]
# Fetching model.ckpt.meta: 1.05Mit [00:00, 4.45Mit/s]
# Fetching vocab.bpe: 1.05Mit [00:00, 5.38Mit/s]

# %%
gpt2.mount_gdrive()
root_dir = '/content/drive/MyDrive/Echidna'
# Out:
# Mounted at /content/drive

# %%
sess = gpt2.start_tf_sess()
gpt2.finetune(sess,
              root_dir + '/data/data.json',
              steps=4000,
              model_name=model_name,
              print_every=10,
              sample_every=200,
              save_every=500,
              run_name='echidna',
              restore_from='fresh'
              ) 
gpt2.copy_checkpoint_to_gdrive(run_name='echidna')
# Out:
# WARNING:tensorflow:From /content/gpt_2_simple/src/sample.py:17: where (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# WARNING:tensorflow:From /content/gpt_2_simple/src/memory_saving_gradients.py:62: get_backward_walk_ops (from tensorflow.contrib.graph_editor.select) is deprecated and will be removed after 2019-06-06.
# Instructions for updating:
# Please use tensorflow.python.ops.op_selector.get_backward_walk_ops.
# Loading checkpoint models/355M/model.ckpt
# INFO:tensorflow:Restoring parameters from models/355M/model.ckpt
# Loading dataset...
# 100%|██████████| 1/1 [00:09<00:00,  9.80s/it]
# dataset has 3277868 tokens
# Training...
# [10 | 22.92] loss=0.61 avg=0.61
# [20 | 37.67] loss=0.78 avg=0.69
# [30 | 52.56] loss=0.62 avg=0.67
# [40 | 67.61] loss=0.53 avg=0.63
# [50 | 82.80] loss=1.09 avg=0.73
# [60 | 98.11] loss=0.98 avg=0.77
# [70 | 113.56] loss=0.77 avg=0.77
# [80 | 129.14] loss=0.45 avg=0.73
# [90 | 144.79] loss=0.24 avg=0.67
# [100 | 160.54] loss=0.29 avg=0.63
# [110 | 176.46] loss=0.50 avg=0.62
# [120 | 192.42] loss=0.41 avg=0.60
# [130 | 208.45] loss=0.26 avg=0.57
# [140 | 224.56] loss=0.25 avg=0.55
# [150 | 240.71] loss=0.15 avg=0.52
# [160 | 256.90] loss=0.22 avg=0.50
# [170 | 272.99] loss=0.24 avg=0.48
# [180 | 289.09] loss=0.39 avg=0.48
# [190 | 305.21] loss=0.30 avg=0.47
# [200 | 321.32] loss=0.17 avg=0.45
# ======== SAMPLE 1 ========
# ", "Attributes": { "Athletic", "Cunning", "Fighter", "Ranged Weapons", "Siege Weapons" }
#           },
#           ],
#          "name_seed_additionalAbilities": "Siege Dragon, isProper=False",
#          "additionalAbilities": [
#              {
#                 "name": "Frightening Roar",
#                 "description": "The siege dragon beats its wings, shaking its body violently."
#              },
#             "name_seed_actions": "Siege Dragon, isProper=False",
#            "actions": [
#               {
#                   "name": "Swarm",
#                   "description": "The siege dragon uses its tentacles, or two tentacles at a time, to grapple another creature it can see within 30 feet of it. The target must make a DC 15 Dexterity saving throw, taking 8 (2d6) psychic damage on a failed save, or half as much on a successful one. The trapped creature must make a DC 15 Dexterity saving throw, taking 9 (2d6) psychic damage on a failed save, or half as much on a successful one."
#              },
#              {
#                  "name": "Tentacles",
#                  "description": "The siege dragon and any creature it grapples must succeed on a DC 15 grapple check or be pulled 15 feet, reaching on a specific appendage. Each creature can see the grapple, and the grappling creature can use its grapple on the same target."
#              }
#          ],
#          "name_seed_reactions": "Siege Dragon, isProper=False",
#          "reactions": [
#              {
#                 "name": "Swarm",
#                 "description": "The siege dragon uses its tentacles, or two tentacles at a time, to grapple another creature it can see within 15 feet of it. The target must make a DC 15 Dexterity saving throw, taking 14 (4d6) psychic damage if it takes psychic damage."
#             }
#         ],
#         "name_seed_legendaryActions": "Siege Dragon, isProper=False",
#         "legendaryActions": [
#             {
#                "name": "Tentacle",
#                "description": "The siege dragon grabs the target and slams it into the ground or a surface of any size, including terrain."
#             }
#         ],
#         "hitDieSize": 9
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Tiger",
#     "flavor": {
#         "description": "",
#         "nameIsProper": false
#     },
#     "stats": {
#         "name_seed_size": "Tiger, isProper=False",
#         "size": "Large",
#         "race": "undead",
#         "alignment": "Lawful Evil",
#
#
# [210 | 360.58] loss=0.71 avg=0.46
# [220 | 376.78] loss=0.21 avg=0.45
# [230 | 392.96] loss=0.17 avg=0.44
# [240 | 409.19] loss=0.33 avg=0.43
# [250 | 425.44] loss=0.77 avg=0.45
# [260 | 441.67] loss=0.17 avg=0.44
# [270 | 457.85] loss=0.31 avg=0.43
# [280 | 474.05] loss=0.23 avg=0.42
# [290 | 490.29] loss=0.21 avg=0.41
# [300 | 506.55] loss=0.30 avg=0.41
# [310 | 522.78] loss=0.46 avg=0.41
# [320 | 539.02] loss=0.16 avg=0.40
# [330 | 555.28] loss=0.52 avg=0.41
# [340 | 571.48] loss=0.46 avg=0.41
# [350 | 587.72] loss=0.30 avg=0.40
# [360 | 603.96] loss=0.39 avg=0.40
# [370 | 620.18] loss=0.15 avg=0.40
# [380 | 636.37] loss=0.27 avg=0.39
# [390 | 652.52] loss=0.19 avg=0.39
# [400 | 668.75] loss=0.23 avg=0.38
# ======== SAMPLE 1 ========
#          "description": "The haggis makes two attacks in reaction:"
#                 "name": "Attack",
#                "description": "The haggis makes its tentacle attack and deals an extra 9 (2d10) damage".
#             },
#             {
#                 "name": "Tentacle",
#                 "description": "<i>Melee Weapon Attack:</i> +2 to hit, reach 5 ft., one creature. <i>Hit:</i> 4 (1d6 + 1) bludgeoning damage. On hit, the target makes a grapple grapple attempt. If failed, the target takes 8 (2d6) claw damage at the time of the grapple."
#            }
#         ],
#         "name_seed_reactions": "Haggis, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Haggis, isProper=False",
#         "legendaryActions": [
#             {
#                "name": "Grapple",
#                "description": "The haggis uses its grapple."
#             }
#         ],
#         "hitDieSize": 8
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Haggis",
#     "flavor": {
#          "description": "",
#          "nameIsProper": false
#     },
#     "stats": {
#          "name_seed_size": "Haggis, isProper=False",
#          "size": "Huge",
#          "race": "beast",
#          "alignment": "Unaligned",
#          "armorType": "",
#          "armorClass": 8,
#          "numHitDie": 12,
#          "speed": "40 ft., burrow 30 ft.",
#          "abilityScores": {
#             "strength": 20,
#             "dexterity": 10,
#             "constitution": 16,
#             "intelligence": 10,
#             "wisdom": 10,
#             "charisma": 10
#         },
#         "proficiencyBonus": 2,
#         "name_seed_damageVulnerabilities": "Haggis, isProper=False",
#         "damageVulnerabilities": [],
#         "damageResistances": [],
#         "damageImmunities": [],
#         "conditionImmunities": [],
#         "senses": [],
#         "languages": [
#            "beast"
#         ],
#         "challengeRating": 7,
#         "experiencePoints": 8500,
#         "legendaryActionsPerRound": 3,
#         "name_seed_legendaryActionsDescription":
#
# [410 | 705.73] loss=0.59 avg=0.39
# [420 | 721.92] loss=0.46 avg=0.39
# [430 | 738.20] loss=0.34 avg=0.39
# [440 | 754.44] loss=0.19 avg=0.38
# [450 | 770.59] loss=0.52 avg=0.39
# [460 | 786.79] loss=0.48 avg=0.39
# [470 | 803.06] loss=0.19 avg=0.38
# [480 | 819.28] loss=0.15 avg=0.38
# [490 | 835.53] loss=0.23 avg=0.37
# [500 | 851.73] loss=0.81 avg=0.38
# Saving checkpoint/echidna/model-500
# [510 | 875.40] loss=0.14 avg=0.38
# [520 | 891.81] loss=0.36 avg=0.38
# [530 | 908.11] loss=0.36 avg=0.38
# [540 | 924.33] loss=0.14 avg=0.37
# [550 | 940.47] loss=0.26 avg=0.37
# [560 | 956.60] loss=0.31 avg=0.37
# [570 | 972.87] loss=0.28 avg=0.37
# [580 | 989.12] loss=0.54 avg=0.37
# [590 | 1005.32] loss=0.44 avg=0.37
# [600 | 1021.54] loss=0.38 avg=0.37
# ======== SAMPLE 1 ========
#      "race": "Humanoid (drow)",
#        "alignment": "Neutral Evil",
#        "armorType": "natural armor",
#        "armorClass": 20,
#        "numHitDie": 12,
#        "speed": "40 ft.",
#        "abilityScores": {
#           "strength": 25,
#           "dexterity": 18,
#           "constitution": 16,
#           "intelligence": 15,
#           "wisdom": 10,
#           "charisma": 12
#        },
#        "proficiencyBonus": 3,
#        "name_seed_damageVulnerabilities": "Drow, isProper=True",
#        "damageVulnerabilities": [],
#        "damageResistances": [],
#        "damageImmunities": [
#            "Chianthe"
#        ],
#        "conditionImmunities": [],
#        "senses": [],
#        "languages": [
#            "Undercommon"
#        ],
#        "challengeRating": 1,
#        "experiencePoints": 200,
#        "legendaryActionsPerRound": 3,
#        "name_seed_legendaryActionsDescription": "Drow, isProper=True",
#        "legendaryActionsDescription": "",
#        "savingThrows": [],
#        "skills": [
#            {
#                "name": "Perception",
#                "proficient": false,
#                "value": 4
#            },
#            {
#                "name": "Persuasion",
#                "proficient": false,
#                "value": 4
#            }
#         ],
#         "name_seed_additionalAbilities": "Drow, isProper=True",
#         "additionalAbilities": [
#            {
#                "name": "Tentacles",
#                "description": "<i>Melee Weapon Attack:</i> +11 to hit, reach 10 ft., one target. <i>Hit:</i> 13 (1d9 + 6) psychic psychic damage, plus 17 (4d10) necrotic damage dealt to the target."
#            },
#            {
#                "name": "Tightened Bites",
#                "description": "<i>Melee Weapon Attack:</i> +6 to hit, reach 5 ft. or reach 1 ft., one target. <i>Hit:</i> 19 (4d10 + 4) necrotic damage."
#             },
#             {
#                 "name": "False Appearance",
#                 "description": "The drow appears in an unoccupied space within
#
# [610 | 1058.66] loss=0.30 avg=0.37
# [620 | 1074.80] loss=0.11 avg=0.36
# [630 | 1091.03] loss=0.28 avg=0.36
# [640 | 1107.28] loss=0.09 avg=0.36
# [650 | 1123.51] loss=0.24 avg=0.35
# [660 | 1139.75] loss=0.46 avg=0.36
# [670 | 1155.99] loss=0.57 avg=0.36
# [680 | 1172.19] loss=0.11 avg=0.36
# [690 | 1188.39] loss=0.64 avg=0.36
# [700 | 1204.61] loss=0.24 avg=0.36
# [710 | 1220.81] loss=0.77 avg=0.37
# [720 | 1237.00] loss=0.16 avg=0.36
# [730 | 1253.20] loss=0.28 avg=0.36
# [740 | 1269.38] loss=0.12 avg=0.36
# [750 | 1285.60] loss=0.21 avg=0.35
# [760 | 1301.79] loss=0.19 avg=0.35
# [770 | 1318.01] loss=0.44 avg=0.35
# [780 | 1334.20] loss=0.12 avg=0.35
# [790 | 1350.37] loss=0.26 avg=0.35
# [800 | 1366.61] loss=0.11 avg=0.34
# ======== SAMPLE 1 ========
#              "description": "Vampire of Valkoria isProper=OnReceive, false",
#          "nameIsProper": false
#     },
#     "stats": {
#         "name_seed_size": "Vandal, isProper=False",
#         "size": "Medium",
#         "race": "human (vampire)",
#         "alignment": "Neutral Evil",
#         "armorType": null,
#         "armorClass": 16,
#         "numHitDie": 14,
#         "speed": "40 ft.",
#         "abilityScores": {
#             "strength": 25,
#             "dexterity": 16,
#             "constitution": 25,
#             "intelligence": 10,
#             "wisdom": 15,
#             "charisma": 17
#         },
#         "proficiencyBonus": 10,
#         "name_seed_damageVulnerabilities": "Vandal, isProper=False",
#         "damageVulnerabilities": [],
#         "damageResistances": [
#             "Poison"
#         ],
#         "damageImmunities": [
#             "Fire",
#             "Poison"
#         ],
#         "conditionImmunities": [
#             "Charmed",
#             "Poisoned"
#         ],
#         "senses": [
#             "darkvision 60ft., passive Perception 14"
#         ],
#         "languages": [
#             "Draconic",
#             "telepathy 60 ft."
#         ],
#         "challengeRating": 11,
#         "experiencePoints": 2900,
#         "legendaryActionsPerRound": 3,
#         "name_seed_legendaryActionsDescription": "Vandal, isProper=False",
#         "legendaryActionsDescription": "",
#         "savingThrows": [],
#         "skills": [
#             {
#                 "name": "Perception",
#                 "value": 6,
#                 "proficient": false
#             }
#         ],
#         "name_seed_additionalAbilities": "Vandal, isProper=False",
#         "additionalAbilities": [
#             {
#                "name": "Amphibious",
#                "description": "The vandal can breathe air and water."
#             },
#             {
#                "name": "Innate Spellcasting",
#
#
# [810 | 1403.51] loss=0.71 avg=0.35
# [820 | 1419.67] loss=0.53 avg=0.35
# [830 | 1435.83] loss=0.26 avg=0.35
# [840 | 1452.02] loss=0.82 avg=0.36
# [850 | 1468.25] loss=0.12 avg=0.35
# [860 | 1484.49] loss=0.34 avg=0.35
# [870 | 1500.68] loss=0.18 avg=0.35
# [880 | 1516.87] loss=0.93 avg=0.36
# [890 | 1533.07] loss=0.29 avg=0.36
# [900 | 1549.27] loss=0.41 avg=0.36
# [910 | 1565.43] loss=0.31 avg=0.36
# [920 | 1581.58] loss=0.23 avg=0.36
# [930 | 1597.80] loss=0.25 avg=0.36
# [940 | 1613.99] loss=0.19 avg=0.35
# [950 | 1630.21] loss=0.16 avg=0.35
# [960 | 1646.44] loss=0.32 avg=0.35
# [970 | 1662.61] loss=0.16 avg=0.35
# [980 | 1678.81] loss=0.10 avg=0.34
# [990 | 1694.99] loss=0.25 avg=0.34
# [1000 | 1711.17] loss=0.57 avg=0.35
# Saving checkpoint/echidna/model-1000
# WARNING:tensorflow:From /tensorflow-1.15.2/python3.7/tensorflow_core/python/training/saver.py:963: remove_checkpoint (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to delete files with this prefix.
# ======== SAMPLE 1 ========
#  prowess_damageMultiplier": 3,
#           "damageResistances": [],
#          "damageImmunities": [],
#          "conditionImmunities": [],
#          "senses": [
#             "darkvision 60 ft."
#         ],
#         "languages": [],
#         "challengeRating": 5,
#         "experiencePoints": 1800,
#         "legendaryActionsPerRound": 3,
#         "name_seed_legendaryActionsDescription": "The Void Spawn, isProper=False",
#         "legendaryActionsDescription": "",
#         "savingThrows": [],
#         "skills": [
#             {
#                 "name": "Insight",
#                 "proficient": true
#             }
#         ],
#         "name_seed_additionalAbilities": "The Void Spawn, isProper=False",
#         "additionalAbilities": [
#             {
#                 "name":  "Corruptive Aura",
#                 "description": "The creature has a foul mote-like cloud that it can breathe, and any creature that touches the cloud or touches it has its speed halved and takes 17 (6d6) psychic damage. The creature can only reroll a d6 it is being affected by this effect at the end of its next turn."
#             }
#         ],
#         "name_seed_actions": "The Void Spawn, isProper=False",
#         "actions": [
#             {
#                 "name": "Multiattack",
#                 "description": "The Spawn makes two attacks: one with its stinger and one with its tentacles. If either attack hits, the target takes 19 (4d8) psychic damage. As a bonus action, the Swarm can use its Corrode action to infect one creature or two creatures at once."
#             }
#         ],
#         "name_seed_reactions": "The Void Spawn, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "The Void Spawn, isProper=False",
#         "legendaryActions": [],
#         "hitDieSize": 10
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "The Waking Sun",
#     "flavor": {
#         "description": "",
#         "nameIsProper": false
#     },
#     "stats": {
#         "name_seed_size": "The Waking Sun, isProper=False",
#         "size": "Large",
#         "race": "fey",
#         "alignment": "Neutral Evil",
#         "armorType": "",
#         "armorClass": 13,
#         "numHitDie": 15,
#         "speed": "0 ft., fly 15 ft.",
#         "abilityScores": {
#
#
# [1010 | 1755.15] loss=0.26 avg=0.34
# [1020 | 1771.33] loss=0.17 avg=0.34
# [1030 | 1787.46] loss=0.29 avg=0.34
# [1040 | 1803.58] loss=0.24 avg=0.34
# [1050 | 1819.77] loss=0.13 avg=0.34
# [1060 | 1836.02] loss=0.51 avg=0.34
# [1070 | 1852.23] loss=0.27 avg=0.34
# [1080 | 1868.46] loss=0.20 avg=0.33
# [1090 | 1884.69] loss=0.30 avg=0.33
# [1100 | 1900.89] loss=0.17 avg=0.33
# [1110 | 1917.11] loss=0.32 avg=0.33
# [1120 | 1933.31] loss=0.63 avg=0.34
# [1130 | 1949.45] loss=0.22 avg=0.33
# [1140 | 1965.63] loss=0.66 avg=0.34
# [1150 | 1981.80] loss=0.74 avg=0.34
# [1160 | 1997.97] loss=0.11 avg=0.34
# [1170 | 2014.20] loss=0.22 avg=0.34
# [1180 | 2030.42] loss=0.81 avg=0.35
# [1190 | 2046.62] loss=0.29 avg=0.35
# [1200 | 2062.82] loss=0.16 avg=0.34
# ======== SAMPLE 1 ========
#  hit nflammable objects in a 20-foot radius, and the object explodes, releasing a burst of black, gas-filled vapors. The area in a 40-foot radius circle the vivis is in is heavily obscured for 5d6 hours, until the end of the vivis\u2019s next turn."
#             },
#             {
#                 "name": "Scorching Ray (Recharge 4-6)",
#                 "description": "The vivis magically creates a bright flash of light in a 10-foot radius, high pressure cylinder. Each creature in the area must succeed on a DC 15 Dexterity saving throw or take 18 (5d8) fire damage. Each creature in that area must regain 10 hit points and be ignited. A creature igniter must make a DC 15 Constitution saving throw or lose a massive amount of hit points and become incapacitated for 1 minute. A character that successfully saves is immune to the fire damage for 1 hour."
#             }
#         ],
#         "name_seed_reactions": "Vivis, the Burning Vengeance Spirit, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Vivis, the Burning Vengeance Spirit, isProper=False",
#         "legendaryActions": [],
#         "hitDieSize": 8
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Void",
#     "flavor": {
#         "description": "<b>Lair Actions:</b>\nAt the end of every dawn, a shadow must make a DC 15 Strength saving throw or fall prone. If the shadow fails, it takes an extra 8 (2d10) bludgeoning damage. If the save is successful or the damage is reduced by half, the shadow is knocked prone. Otherwise, it is restrained for 1 minute. A creature can repeat the saving throw at the end of each of its turns, ending the effect on itself on a success. If a creature is slain by this effect, it is instantly petrified. A creature restrained by this effect is blinded and can't take any other actions or benefit from reactions."
#         },
#         "name_seed_reactions": "Void, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Void, isProper=False",
#         "hitDieSize": 5
#     },
#     "stats": {
#         "name_seed_size": "Void, isProper=False",
#         "size": "Medium",
#         "race": "Abberation, the Burning Swarm",
#         "alignment": "Chaotic Evil",
#         "armorType": "Natural Armor",
#         "armorClass": 13,
#         "numHitDie": 11,
#         "speed": "30 ft.",
#         "abilityScores": {
#             "strength": 15,
#             "dexterity": 15,
#             "constitution": 14,
#             "intelligence": 14,
#             "wisdom": 18,
#             "charisma": 12
#         },
#         "proficiencyBonus": 4,
#         "name_seed_damageVulnerabilities": "Void, isProper=False",
#         "damageVulnerabilities": [
#             "Necrotic
#
# [1210 | 2099.75] loss=0.12 avg=0.34
# [1220 | 2115.91] loss=0.21 avg=0.34
# [1230 | 2132.11] loss=0.14 avg=0.34
# [1240 | 2148.30] loss=0.14 avg=0.33
# [1250 | 2164.49] loss=0.38 avg=0.33
# [1260 | 2180.72] loss=0.22 avg=0.33
# [1270 | 2196.88] loss=0.19 avg=0.33
# [1280 | 2213.12] loss=0.12 avg=0.33
# [1290 | 2229.36] loss=0.12 avg=0.32
# [1300 | 2245.59] loss=0.11 avg=0.32
# [1310 | 2261.83] loss=0.18 avg=0.32
# [1320 | 2278.10] loss=0.44 avg=0.32
# [1330 | 2294.34] loss=0.45 avg=0.32
# [1340 | 2310.56] loss=0.23 avg=0.32
# [1350 | 2326.81] loss=0.41 avg=0.32
# [1360 | 2343.07] loss=0.53 avg=0.33
# [1370 | 2359.31] loss=0.50 avg=0.33
# [1380 | 2375.55] loss=0.10 avg=0.32
# [1390 | 2391.79] loss=0.10 avg=0.32
# [1400 | 2408.05] loss=0.46 avg=0.32
# ======== SAMPLE 1 ========
#  oil from a dead creature, each creature within 10 feet of the creature is within 5 feet of the corpse and taking 7 (2d6) necrotic damage."
#             },
#             {
#                 "name": "Flaming Bites",
#                 "description": "<i>Melee Weapon Attack:</i> +5 to hit, reach 5 ft., one creature. <i>Hit:</i> 9 (2d8) necrotic damage. If the target is a creature, it must succeed on a DC 12 Dexterity saving throw or its skin burns, becoming flammable."
#             },
#             {
#                 "name": "Flaming Glaive",
#                 "description": "<i>Melee Weapon Attack:</i> +5 to hit, reach 5 ft., one creature. <i>Hit:</i> 6 (1d6 + 3) slashing damage."
#             },
#             {
#                 "name": "Longbow",
#                 "description": "<i>Ranged Weapon Attack:</i> +4 to hit, range 150/400 ft., one creature. <i>Hit:</i> 4 (1d8) piercing damage."
#             }
#         ],
#         "name_seed_reactions": "Piercer, isProper=True",
#         "reactions": [],
#         "name_seed_legendaryActions": "Piercer, isProper=True",
#         "legendaryActions": [
#             {
#                 "name": "Detect",
#                 "description": "The piercer makes a Wisdom (Perception) check."
#             },
#             {
#                 "name": "Detect Object",
#                 "description": "The piercer makes a successful Wisdom (Perception) check."
#             },
#             {
#                 "name": "Detect Magical Weapons",
#                 "description": "The piercer makes a successful Intelligence (perception) check."
#             }
#         ],
#         "name_seed_reactions": "Piercer, isProper=True",
#         "reactions": [
#             {
#                 "name": "Attack",
#                 "description": "The piercer makes a successful attack."
#             },
#             {
#                 "name": "Ape (Cape Crab)",
#                 "description": "The piercer makes a successful climbing attack"
#             },
#             {
#                 "name": "Ranged Weapon Attack: +4 to hit, range 30/60 ft., one creature. <i>Hit:</i> 4 (1d8
#
# [1410 | 2445.17] loss=0.17 avg=0.32
# [1420 | 2461.30] loss=0.08 avg=0.32
# [1430 | 2477.49] loss=0.55 avg=0.32
# [1440 | 2493.65] loss=0.26 avg=0.32
# [1450 | 2509.88] loss=0.31 avg=0.32
# [1460 | 2526.09] loss=0.13 avg=0.32
# [1470 | 2542.34] loss=0.10 avg=0.31
# [1480 | 2558.57] loss=0.14 avg=0.31
# [1490 | 2574.81] loss=0.47 avg=0.31
# [1500 | 2591.06] loss=0.25 avg=0.31
# Saving checkpoint/echidna/model-1500
# [1510 | 2614.02] loss=0.18 avg=0.31
# [1520 | 2630.36] loss=0.11 avg=0.31
# [1530 | 2646.64] loss=0.13 avg=0.31
# [1540 | 2662.82] loss=0.11 avg=0.30
# [1550 | 2679.00] loss=0.14 avg=0.30
# [1560 | 2695.19] loss=0.13 avg=0.30
# [1570 | 2711.43] loss=0.20 avg=0.30
# [1580 | 2727.68] loss=0.38 avg=0.30
# [1590 | 2743.87] loss=0.17 avg=0.30
# [1600 | 2760.06] loss=0.08 avg=0.30
# ======== SAMPLE 1 ========
#         "ability": "charisma",
#                 "value": 10,
#                 "proficient": false
#             }
#         ],
#         "skills": [
#             {
#                 "name": "Deception",
#                 "value": 10,
#                 "proficient": false
#             },
#             {
#                 "name": "Perception",
#                 "value": 15,
#                 "proficient": false
#             },
#             {
#                 "name": "Stealth",
#                 "value": 12,
#                 "proficient": false
#             },
#             {
#                 "name": "Survival",
#                 "value": 10,
#                 "proficient": false
#             }
#         ],
#         "name_seed_additionalAbilities": "Black Bear Skeleton, isProper=False",
#         "additionalAbilities": [
#             {
#                 "name": "Carcass Touch",
#                 "description": "If the bear is touching a creature and the touch would kill it, the target takes no damage and is instead grappled. If the bear ends its turn inside a creature instead, the bear gets a bonus to its AC against the touch equal to the amount the creature was killed. The bear can have only one target inside it at one time."
#             },
#             {
#                 "name": "Innate Spellcasting",
#                 "description": "The black bear is a 12th-level spellcaster. Its innate spellcasting ability is Charisma (spell save DC 17, +9 to hit with spell attacks). It can innately cast the following spells, requiring no material components:\n\nAt will: minor illusion (Bear Form only)",
#              }
#         ],
#         "name_seed_actions": "Black Bear Skeleton, isProper=False",
#         "actions": [
#             {
#                 "name": "Multiattack",
#                 "description": "The bear makes two bite attacks."
#             },
#             {
#                 "name": "Bite",
#                 "description": "<i>Melee Weapon Attack:</i> +7 to hit, reach 5 ft., one target. <i>Hit:</i> 6 (1 d6 + 4) piercing damage."
#             },
#
#
# [1610 | 2796.98] loss=0.23 avg=0.29
# [1620 | 2813.15] loss=0.27 avg=0.29
# [1630 | 2829.38] loss=0.08 avg=0.29
# [1640 | 2845.53] loss=0.26 avg=0.29
# [1650 | 2861.74] loss=0.13 avg=0.29
# [1660 | 2877.96] loss=0.41 avg=0.29
# [1670 | 2894.20] loss=0.21 avg=0.29
# [1680 | 2910.45] loss=0.36 avg=0.29
# [1690 | 2926.69] loss=0.12 avg=0.29
# [1700 | 2942.96] loss=0.21 avg=0.29
# [1710 | 2959.22] loss=0.59 avg=0.29
# [1720 | 2975.47] loss=0.57 avg=0.29
# [1730 | 2991.69] loss=0.77 avg=0.30
# [1740 | 3007.92] loss=0.22 avg=0.30
# [1750 | 3024.15] loss=0.17 avg=0.30
# [1760 | 3040.37] loss=0.11 avg=0.30
# [1770 | 3056.59] loss=0.32 avg=0.30
# [1780 | 3072.82] loss=0.09 avg=0.29
# [1790 | 3089.05] loss=0.50 avg=0.30
# [1800 | 3105.20] loss=0.47 avg=0.30
# ======== SAMPLE 1 ========
# Spectuators are alerted to the presence of creatures from this creature by the creature's voice.
# \nIf any creatures in the space or near the spectuator are killed, the creature's body disintegrates, and all those within 5 feet of it are silenced.
# \nThe spectuator obeys all the same laws that a regular spectator does.
# \nOnce per turns, the spectuator can use an action to cast the following spells from its list, but not from its spell list: disintegrate, hold person, legend lore, legend lore\u2022 , locate creature\u2022 "
#            },
#            {
#                 "name": "Specter Detection",
#                 "description": "The spectuator makes a Wisdom (Perception) check to see if a humanoid has slain a spirit or is telepathic."
#             },
#             {
#                  "name": "Spirit Detection",
#                  "description": "The spectuator makes a Wisdom (Perception) check to sense if a spirit is in the area."
#              }
#         ],
#         ],
#         "name_seed_reactions": "Specter Vanish, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Specter Vanish, isProper=False",
#         "legendaryActions": [
#             {
#                 "name": "Detect Mind",
#                  "description": "The spectuator makes a Wisdom (Perception) check."
#              },
#              {
#                  "name": "Shatter",
#                   "description": "The spectuator magically bursts with power and the creature must make a DC 17 Wisdom saving throw or be stunned until the end of the spectuator's next turn."
#              },
#              {
#                  "name": "Summon Specter (Costs 2 Actions)",
#                  "description": "The spectuator magically targets one creature that the spectuator can see within 120 ft. of it. The spectuator can have no more than four spectuators within 120 ft. of the target at one time."
#              },
#              {
#                  "name": "Teleport (Costs 1-3 Actions)",
#                  "description": "The spectuator magically teleports up to 40 ft. in a direction it chooses. The spectuator must use its action to stop and resume its movement. The spectuator doesn\u2019t need to act, and its speed is irrelevant. It teleports only if it's on a plane."
#               },
#               {
#                   "name": "Regeneration (Costs 1-7 Actions)",
#                   "description": "The spectuator regains 30 hit points at the start of its turn if it has a Constitution score of 15 or more. If the spectuator takes radiant damage, this trait doesn\u2019t function at the start of the spectuator\u2019
#
# [1810 | 3142.12] loss=0.12 avg=0.30
# [1820 | 3158.29] loss=0.85 avg=0.30
# [1830 | 3174.44] loss=0.44 avg=0.30
# [1840 | 3190.57] loss=0.12 avg=0.30
# [1850 | 3206.75] loss=0.10 avg=0.30
# [1860 | 3222.91] loss=0.29 avg=0.30
# [1870 | 3239.12] loss=0.21 avg=0.30
# [1880 | 3255.35] loss=0.12 avg=0.30
# [1890 | 3271.57] loss=0.24 avg=0.30
# [1900 | 3287.82] loss=0.51 avg=0.30
# [1910 | 3304.05] loss=0.46 avg=0.30
# [1920 | 3320.27] loss=0.63 avg=0.30
# [1930 | 3336.48] loss=0.52 avg=0.31
# [1940 | 3352.71] loss=0.09 avg=0.30
# [1950 | 3368.94] loss=0.12 avg=0.30
# [1960 | 3385.17] loss=0.08 avg=0.30
# [1970 | 3401.39] loss=0.20 avg=0.30
# [1980 | 3417.62] loss=0.28 avg=0.30
# [1990 | 3433.82] loss=0.56 avg=0.30
# [2000 | 3449.99] loss=0.72 avg=0.31
# Saving checkpoint/echidna/model-2000
# ======== SAMPLE 1 ========
#         "name": "Vile Chill",
#              "description": "The gendrome makes a melee attack or has its speed lowered by half."
#            },
#            {
#                "name": "Poison Spit",
#                "description": "Range Weapon Attack: +5 to hit, one creature. Hit: 6 (1d8 + 3) poison damage."
#             }
#         ],
#         "name_seed_reactions": "Gendrome (Crows Nest Dragon), isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Gendrome (Crows Nest Dragon), isProper=False",
#         "legendaryActions": [],
#         "hitDieSize": 10
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Glaltooth",
#     "flavor": {
#         "description": "",
#         "nameIsProper": false
#     },
#     "stats": {
#         "name_seed_size": "Glaltooth, isProper=False",
#         "size": "Huge",
#         "race": "dragon",
#         "alignment": "Chaotic Good",
#         "armorType": "",
#         "armorClass": 17,
#         "numHitDie": 18,
#         "speed": "40 ft., fly 80 ft., swim 60 ft.",
#         "abilityScores": {
#             "strength": 27,
#             "dexterity": 16,
#             "constitution": 22,
#             "intelligence": 14,
#             "wisdom": 12,
#             "charisma": 15
#         },
#         "proficiencyBonus": 5,
#         "name_seed_damageVulnerabilities": "Glaltooth, isProper=False",
#         "damageVulnerabilities": [],
#         "damageResistances": [],
#         "damageImmunities": [],
#         "conditionImmunities": [],
#         "senses": [
#             "darkvision 120 ft."
#         ],
#         "languages": [
#             "Draconic"
#         ],
#         "challengeRating": 12,
#         "experiencePoints": 8400,
#         "legendaryActionsPerRound": 3,
#         "name_seed_legendaryActionsDescription": "Glaltooth, isProper=False",
#         "legendaryActionsDescription": "",
#         "savingThrows": [
#             {
#                 "ability": "dexterity",
#                 "value": 9,
#                 "proficient": false
#             },
#
#
# [2010 | 3494.05] loss=0.08 avg=0.30
# [2020 | 3510.25] loss=0.47 avg=0.31
# [2030 | 3526.41] loss=0.32 avg=0.31
# [2040 | 3542.55] loss=0.24 avg=0.30
# [2050 | 3558.74] loss=0.16 avg=0.30
# [2060 | 3574.96] loss=0.10 avg=0.30
# [2070 | 3591.18] loss=0.14 avg=0.30
# [2080 | 3607.43] loss=0.15 avg=0.30
# [2090 | 3623.62] loss=1.72 avg=0.31
# [2100 | 3639.78] loss=0.47 avg=0.32
# [2110 | 3655.94] loss=0.38 avg=0.32
# [2120 | 3672.08] loss=0.10 avg=0.31
# [2130 | 3688.22] loss=0.47 avg=0.32
# [2140 | 3704.40] loss=0.13 avg=0.31
# [2150 | 3720.60] loss=0.10 avg=0.31
# [2160 | 3736.77] loss=0.30 avg=0.31
# [2170 | 3752.95] loss=0.14 avg=0.31
# [2180 | 3769.13] loss=0.14 avg=0.31
# [2190 | 3785.30] loss=0.14 avg=0.30
# [2200 | 3801.48] loss=0.26 avg=0.30
# ======== SAMPLE 1 ========
#    "damageResistances": [],
#        "damageImmunities": [],
#         "conditionImmunities": [],
#         "senses": [
#             "Truesight 120 ft."
#         ],
#         "languages": [
#             "Understands all languages and all the languages of its species but can't speak",
#             "Understands all languages and all the languages of its species but can't speak"
#         ],
#         "challengeRating": 11,
#         "experiencePoints": 7200,
#         "legendaryActionsPerRound": 3,
#         "name_seed_legendaryActionsDescription": "Crimson Fatalis (Dark Light Dragon), isProper=False",
#         "legendaryActionsDescription": "",
#         "savingThrows": [
#             {
#                 "ability": "dexterity",
#                 "proficient": true
#             },
#             {
#                 "ability": "wisdom",
#                 "proficient": true
#             },
#             {
#                 "ability": "charisma",
#                 "proficient": true
#             }
#         ],
#         "skills": [
#             {
#                 "name": "Arcana",
#                 "proficient": false,
#                 "value": 12
#             },
#             {
#                 "name": "Intimidation",
#                 "proficient": true
#             },
#             {
#                 "name": "Perception",
#                 "proficient": true
#             }
#         ],
#         "name_seed_additionalAbilities": "Crimson Fatalis (Dark Light Dragon), isProper=False",
#         "additionalAbilities": [
#             {
#                 "name": "Dark Light",
#                 "description": "The fatalis is vulnerable to harm while in dark light. While in darkness, its speed is reduced by 30 feet and that of its attacks is reduced by half."
#             },
#             {
#                 "name": "False Appearance",
#                 "description": "While the fatalis remains motionless, it is indistinguishable from an object in other, warmer worlds."
#             },
#             {
#
#
# [2210 | 3838.40] loss=0.30 avg=0.30
# [2220 | 3854.55] loss=0.15 avg=0.30
# [2230 | 3870.75] loss=0.21 avg=0.30
# [2240 | 3886.98] loss=0.24 avg=0.30
# [2250 | 3903.24] loss=0.29 avg=0.30
# [2260 | 3919.45] loss=0.51 avg=0.30
# [2270 | 3935.59] loss=0.09 avg=0.30
# [2280 | 3951.75] loss=0.06 avg=0.30
# [2290 | 3967.89] loss=0.15 avg=0.30
# [2300 | 3984.10] loss=0.55 avg=0.30
# [2310 | 4000.25] loss=0.09 avg=0.30
# [2320 | 4016.44] loss=0.35 avg=0.30
# [2330 | 4032.62] loss=0.25 avg=0.30
# [2340 | 4048.82] loss=1.13 avg=0.31
# [2350 | 4065.04] loss=0.23 avg=0.31
# [2360 | 4081.27] loss=0.31 avg=0.31
# [2370 | 4097.49] loss=0.15 avg=0.30
# [2380 | 4113.67] loss=0.11 avg=0.30
# [2390 | 4129.91] loss=0.21 avg=0.30
# [2400 | 4146.11] loss=0.62 avg=0.30
# ======== SAMPLE 1 ========
# False "proficient": true
#              },
#              {
#                  "ability": "constitution",
#                 "proficient": true
#              }
#          ],
#          "skills": [],
#          "name_seed_additionalAbilities": "Jinx, the Loose Cannon, isProper=False",
#          "additionalAbilities": [
#              {
#                  "ability": "constitution",
#                  "proficient": false,
#                  "value": 9
#              },
#              {
#                  "ability": "wisdom",
#                  "proficient": true
#              },
#              {
#                  "ability": "charisma",
#                  "proficient": true
#              }
#         ],
#         "name_seed_actions": "Jinx, the Loose Cannon, isProper=False",
#         "actions": [
#             {
#                 "name": "Quarterstaff",
#                 "description": "Melee Weapon Attack: +6 to hit, range 30/120 ft., one creature. Hit: 8 (1d8 plus 6) bludgeoning damage"
#             },
#             {
#                 "name": "Dart",
#                 "description": "Ranged Weapon Attack: +6 to hit, range 30/120 ft., one target. Hit: 7 (1d6 + 4) piercing damage."
#             }
#         ],
#         "name_seed_reactions": "Jinx, the Loose Cannon, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Jinx, the Loose Cannon, isProper=False",
#         "legendaryActions": [],
#         "hitDieSize": 8
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Jeff Varner",
#     "flavor": {
#         "description": "If you are familiar with Magic Items and have been studying items since childhood, you will be surprised to learn that they are very different from normal items like a normal magic item. They are usually created as quest rewards, or to assist you with a divine spell, or a magic attack.",
#         "nameIsProper": true
#     },
#     "stats": {
#         "name_seed_size": "Jeff Varner, isProper=True",
#         "size": "Large",
#         "race": "Humanoid",
#         "alignment": "Chaotic Evil",
#         "armorType": "12, 10, 10, +1 scale natural armor",
#
# [2410 | 4182.99] loss=0.10 avg=0.30
# [2420 | 4199.12] loss=0.41 avg=0.30
# [2430 | 4215.23] loss=0.25 avg=0.30
# [2440 | 4231.41] loss=0.19 avg=0.30
# [2450 | 4247.64] loss=0.37 avg=0.30
# [2460 | 4263.88] loss=0.86 avg=0.31
# [2470 | 4280.10] loss=0.10 avg=0.31
# [2480 | 4296.29] loss=0.08 avg=0.30
# [2490 | 4312.50] loss=0.09 avg=0.30
# [2500 | 4328.74] loss=0.12 avg=0.30
# Saving checkpoint/echidna/model-2500
# [2510 | 4351.67] loss=1.04 avg=0.31
# [2520 | 4368.03] loss=0.12 avg=0.30
# [2530 | 4384.33] loss=0.09 avg=0.30
# [2540 | 4400.48] loss=0.12 avg=0.30
# [2550 | 4416.59] loss=0.21 avg=0.30
# [2560 | 4432.78] loss=0.24 avg=0.30
# [2570 | 4448.99] loss=0.18 avg=0.30
# [2580 | 4465.23] loss=0.11 avg=0.30
# [2590 | 4481.43] loss=0.14 avg=0.29
# [2600 | 4497.64] loss=0.81 avg=0.30
# ======== SAMPLE 1 ========
#  aspect in which it has advantage over the targets of its gaze."
#             }
#         ],
#         "name_seed_actions": "Ape Skeleton, isProper=False",
#         "actions": [
#             {
#                "name": "Bite",
#                 "description": "<i>Melee Weapon Attack:</i> +4 to hit, reach 5 ft., one target. <i>Hit:</i> 3 (1d4 \u2014 1) slashing damage."
#             }
#         ],
#         "name_seed_reactions": "Ape Skeleton, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Ape Skeleton, isProper=False",
#         "legendaryActions": [],
#         "hitDieSize": 8
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Aptonoth",
#     "flavor": {
#         "description": "",
#         "nameIsProper": false
#     },
#     "stats": {
#         "name_seed_size": "Aptonoth, isProper=False",
#         "size": "Small",
#         "race": "Elemental",
#         "alignment": "Tiefling",
#         "armorType": "natural armor",
#         "armorClass": 12,
#         "numHitDie": 1,
#         "speed": "fly 20 ft., swim 20 ft.",
#         "abilityScores": {
#             "strength": 6,
#             "dexterity": 14,
#             "constitution": 12,
#             "intelligence": 2,
#             "wisdom": 13,
#             "charisma": 15
#         },
#         "proficiencyBonus": 2,
#         "name_seed_damageVulnerabilities": "Aptonoth, isProper=False",
#         "damageVulnerabilities": [],
#         "damageResistances": [],
#         "damageImmunities": [],
#         "conditionImmunities": [],
#         "senses": [],
#         "languages": [
#             "Gnoll",
#             "Draconic"
#         ],
#         "challengeRating": 0.8,
#         "experiencePoints": 50,
#         "legendaryActionsPerRound": 3,
#         "name_seed_legendaryActionsDescription": "Aptonoth, isProper=False",
#         "legendaryActionsDescription": "",
#         "savingThrows": [],
#         "skills": [],
#         "name_seed_additionalAbilities": "Aptonoth, isProper=False",
#         "additionalAbilities": [
#             {
#
#
# [2610 | 4534.56] loss=0.15 avg=0.30
# [2620 | 4550.69] loss=0.14 avg=0.30
# [2630 | 4566.89] loss=0.40 avg=0.30
# [2640 | 4583.08] loss=0.11 avg=0.30
# [2650 | 4599.33] loss=0.06 avg=0.29
# [2660 | 4615.55] loss=0.08 avg=0.29
# [2670 | 4631.77] loss=0.17 avg=0.29
# [2680 | 4647.95] loss=0.09 avg=0.29
# [2690 | 4664.14] loss=0.37 avg=0.29
# [2700 | 4680.36] loss=0.26 avg=0.29
# [2710 | 4696.62] loss=0.11 avg=0.29
# [2720 | 4712.81] loss=0.33 avg=0.29
# [2730 | 4728.99] loss=0.06 avg=0.28
# [2740 | 4745.16] loss=0.05 avg=0.28
# [2750 | 4761.32] loss=0.46 avg=0.28
# [2760 | 4777.50] loss=0.43 avg=0.28
# [2770 | 4793.70] loss=0.18 avg=0.28
# [2780 | 4809.90] loss=0.17 avg=0.28
# [2790 | 4826.13] loss=0.15 avg=0.28
# [2800 | 4842.31] loss=0.14 avg=0.28
# ======== SAMPLE 1 ========
#  roll. After hitting the target, the dragon can make one gore attack against up to one creature the dragon is grappling on the same grapple."
#            }
#         ],
#         "name_seed_reactions": "Mummified Ogre, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Mummified Ogre, isProper=False",
#         "legendaryActions": [],
#         "hitDieSize": 10
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Mummified Rat",
#     "flavor": {
#         "description": "",
#         "nameIsProper": false
#     },
#     "stats": {
#         "name_seed_size": "Mummified Rat, isProper=False",
#         "size": "Medium",
#         "race": "Abberation",
#         "alignment": "Unaligned",
#         "armorType": "Plate and Shield",
#         "armorClass": 15,
#         "numHitDie": 5,
#         "speed": "45 ft, climb 30 ft",
#         "abilityScores": {
#             "strength": 16,
#             "dexterity": 9,
#             "constitution": 11,
#             "intelligence": 5,
#             "wisdom": 7,
#             "charisma": 1
#         },
#         "proficiencyBonus": 0,
#         "name_seed_damageVulnerabilities": "Mummified Rat, isProper=False",
#         "damageVulnerabilities": [],
#         "damageResistances": [],
#         "damageImmunities": [],
#         "conditionImmunities": [],
#         "senses": [
#             "Darkvision 120 ft."
#         ],
#         "languages": [],
#         "challengeRating": 0.5,
#         "experiencePoints": 100,
#         "legendaryActionsPerRound": 3,
#         "name_seed_legendaryActionsDescription": "Mummified Rat, isProper=False",
#         "legendaryActionsDescription": "",
#         "savingThrows": [
#             "ability": "strength",
#             "proficient": false,
#             "value": 4
#            }
#         ],
#         "skills": [
#             {
#                 "name": "Perception",
#                 "proficient": false,
#                 "value": 3
#             }
#         ],
#         "name_seed_additionalAbilities": "Mummified Rat, isProper=False",
#         "additionalAbilities": [
#
#
# [2810 | 4879.27] loss=0.13 avg=0.28
# [2820 | 4895.40] loss=0.23 avg=0.28
# [2830 | 4911.61] loss=0.94 avg=0.28
# [2840 | 4927.83] loss=0.08 avg=0.28
# [2850 | 4944.06] loss=0.10 avg=0.28
# [2860 | 4960.27] loss=0.19 avg=0.28
# [2870 | 4976.41] loss=0.11 avg=0.28
# [2880 | 4992.60] loss=0.23 avg=0.28
# [2890 | 5008.76] loss=0.30 avg=0.28
# [2900 | 5024.94] loss=0.14 avg=0.28
# [2910 | 5041.12] loss=0.14 avg=0.27
# [2920 | 5057.31] loss=0.20 avg=0.27
# [2930 | 5073.50] loss=0.09 avg=0.27
# [2940 | 5089.71] loss=0.15 avg=0.27
# [2950 | 5105.94] loss=0.38 avg=0.27
# [2960 | 5122.13] loss=0.11 avg=0.27
# [2970 | 5138.36] loss=0.72 avg=0.27
# [2980 | 5154.60] loss=0.37 avg=0.28
# [2990 | 5170.80] loss=0.18 avg=0.27
# [3000 | 5187.01] loss=0.14 avg=0.27
# Saving checkpoint/echidna/model-3000
# ======== SAMPLE 1 ========
#
#             },
#            {
#               {
#                 "name": "Keen Hearing and Sight",
#                 "description": "Petrification and Deception",
#                "value": 5,
#                "proficient": false
#             }
#         ],
#         "name_seed_actions": "Yuan-ti Nightmare Speaker, isProper=False",
#          "actions": [
#             {
#                "name": "Multiattack",
#                "description": "The nightmare speaker makes two bite attacks and two claw attacks."
#             },
#             {
#                "name": "Bite",
#                "description": "<i>Melee Weapon Attack:</i> +9 to hit, reach 5 ft., one creature. <i>Hit:</i> 7 (1d6 + 5) piercing damage. If the nightmare speaker has advantage on the attack roll, the target instead takes 13 (2d8) necrotic damage."
#             },
#             {
#                "name": "Claw",
#                "description": "<i>Melee Weapon Attack:</i> +9 to hit, reach 5 ft., one creature. <i>Hit:</i> 7 (1d6 + 5) slashing damage."
#             },
#             {
#                "name": "Bite",
#                "description": "<i>Melee Weapon Attack:</i> +9 to hit, reach 5 ft., one creature. <i>Hit:</i> 10 (4d6 + 3) piercing damage."
#             }
#         ],
#         "name_seed_reactions": "Yuan-ti Nightmare Speaker, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Yuan-ti Nightmare Speaker, isProper=False",
#         "legendaryActions": [],
#         "hitDieSize": 8
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Yuan-ti Broodwar",
#     "flavor": {
#         "description": "<i>\"A serpent of dust, a yu-ti is a powerful and unique broodlord. Its scales are used as both a camouflage layer and also as a means of sustenance in some instances. Its small size and powerful strength, coupled with the dust it collects, makes it easy to see why it would be the favoured brood leader among the yu-ti brood.\"</i>\n\nYuan-ti Broodwar is a passive beast; it looks as though all yu-ti have died while they wait for the right moment to attack. In most instances, the Yuan-ti Broodwar is also accompanied by a pair of serpents which guard the corpse; these serpents would look similar to the ones found under the yu-ti's shell for the first few moments of its appearance.\n\n### Combat\nA yuan-ti brood warfare is all about fighting the Yuan-ti Broodwar with all the strength of its Yuan-ti Broodmate.","
#        "nameIsProper":
#
# [3010 | 5231.01] loss=0.15 avg=0.27
# [3020 | 5247.17] loss=0.09 avg=0.27
# [3030 | 5263.33] loss=0.14 avg=0.27
# [3040 | 5279.54] loss=0.15 avg=0.27
# [3050 | 5295.79] loss=0.11 avg=0.27
# [3060 | 5312.02] loss=0.09 avg=0.26
# [3070 | 5328.21] loss=0.63 avg=0.27
# [3080 | 5344.41] loss=0.23 avg=0.27
# [3090 | 5360.61] loss=0.33 avg=0.27
# [3100 | 5376.79] loss=0.08 avg=0.27
# [3110 | 5392.97] loss=0.11 avg=0.26
# [3120 | 5409.13] loss=0.10 avg=0.26
# [3130 | 5425.29] loss=0.14 avg=0.26
# [3140 | 5441.45] loss=0.30 avg=0.26
# [3150 | 5457.64] loss=0.11 avg=0.26
# [3160 | 5473.81] loss=0.03 avg=0.26
# [3170 | 5490.01] loss=0.17 avg=0.26
# [3180 | 5506.21] loss=0.26 avg=0.26
# [3190 | 5522.39] loss=0.51 avg=0.26
# [3200 | 5538.57] loss=0.18 avg=0.26
# ======== SAMPLE 1 ========
#   "name": "Claw",
#                "description": "<i>Melee Weapon Attack:</i> +12 to hit, reach 5 ft., one target. <i>Hit:</i> 21 (4d8 + 8) slashing damage. If the target is a creature, it must succeed on a DC 15 Constitution saving throw or be paralyzed until the end of the demon\u2019s next turn."
#             },
#             {
#                 "name": "Breath Breath (Recharge 5-6)",
#                 "description": "The demon uses one of the following breath weapons.\n<b>Fire Breath.</b> The demon exhales fire in a 90- foot line that is 5 feet wide. Each creature in that line must make a DC 20 Dexterity saving throw, taking 70 (20d8) fire damage on a failed save, or half as much damage on a successful one.\n<b>Hex.</b> The demon exhales fire in a cone. Each creature in that area must make a DC 20 Dexterity saving throw, taking 70 (20d8) fire damage on a failed save, or half as much damage on a successful one.\n<b>Necrotic Breath.</b> The demon exhales fire in a line that is 10 feet long and 15 feet wide. Each creature in that line must make a DC 20 Strength saving throw, taking 10 (l7d8) necrotic damage and being knocked prone on a failed save and only taking half as much damage and not being knocked prone on a successful one.\n<b>Piercing Breath.</b> The demon exhales fire in a line that is 15 feet long and 15 feet wide. Each creature in that line must make a DC 22 Dexterity saving throw. A creature takes 11 (2d6 + 8) piercing damage and is blinded until the end of the demon\u2019s next turn."
#              }
#         ],
#         "name_seed_reactions": "Voidwraith, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Vwraith, isProper=False",
#         "legendaryActions": [
#             {
#                 "name": "Tentacle Bite",
#                 "description": "<i>Melee Weapon Attack:</i> +10 to hit, reach 5 ft., one target. <i>Hit:</i> 16 (3d6 + 7) piercing damage."
#             },
#             {
#                 "name": "Mimicry",
#                 "description": "If the vampire takes damage, every target within 1 mile of it must make a DC 18 Constitution saving throw. On a failed save, a target takes half as much damage and isn\u2019t attacked at all. If a target\u2019s saving throw is successful or the attack is stopped, the target takes half as much damage and isn\u2019t attacked at all. Once the attack or defense has prevented more than half as much damage as the target takes, the target is immune to the blinded condition for the next 24 hours."
#             }
#         ],
#         "hitDieSize": 10
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Vegepygmy",
#     "flavor": {
#         "description": "",
#         "nameIsProper": false
#     },
#     "stats": {
#         "name_seed_size": "Vegepygmy, isProper=False",
#         "size": "Large",
#
#
# [3210 | 5575.47] loss=0.30 avg=0.26
# [3220 | 5591.65] loss=0.12 avg=0.26
# [3230 | 5607.85] loss=0.15 avg=0.26
# [3240 | 5624.07] loss=1.57 avg=0.27
# [3250 | 5640.30] loss=0.15 avg=0.27
# [3260 | 5656.50] loss=0.15 avg=0.27
# [3270 | 5672.66] loss=0.10 avg=0.27
# [3280 | 5688.81] loss=0.09 avg=0.26
# [3290 | 5705.03] loss=0.44 avg=0.27
# [3300 | 5721.30] loss=0.25 avg=0.27
# [3310 | 5737.54] loss=0.08 avg=0.26
# [3320 | 5753.74] loss=0.25 avg=0.26
# [3330 | 5769.87] loss=0.19 avg=0.26
# [3340 | 5786.15] loss=0.15 avg=0.26
# [3350 | 5802.42] loss=0.07 avg=0.26
# [3360 | 5818.66] loss=0.07 avg=0.26
# [3370 | 5834.90] loss=0.10 avg=0.26
# [3380 | 5851.13] loss=0.28 avg=0.26
# [3390 | 5867.32] loss=0.28 avg=0.26
# [3400 | 5883.52] loss=0.11 avg=0.25
# ======== SAMPLE 1 ========
#  "flattened",
#         "slovened"
#        ],
#        "name_seed_legendaryActions": "Drow Blade, isProper=False",
#        "legendaryActions": [],
#        "hitDieSize": 6
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Elder of Gondor",
#     "flavor": {
#         "description": "",
#         "nameIsProper": false
#     },
#     "stats": {
#         "name_seed_size": "Elder of Gondor, isProper=False",
#         "size": "Medium",
#         "race": "Humanoid",
#         "alignment": "Chaotic Neutral Evil",
#         "armorType": '",
#         "armorClass": 17,
#         "numHitDie": 5,
#         "speed": "30 ft.",
#         "abilityScores": {
#              "strength": 13,
#              "dexterity": 20,
#              "constitution": 13,
#              "intelligence": 5,
#              "wisdom": 12,
#              "charisma": 2
#         },
#         "proficiencyBonus": 0,
#         "name_seed_damageVulnerabilities": "Elder of Gondor, isProper=False",
#         "damageVulnerabilities": [],
#         "damageResistances": [],
#         "damageImmunities": [],
#         "conditionImmunities": [],
#         "senses": [],
#         "languages": [
#             "Common"
#         ],
#         "challengeRating": 2,
#         "experiencePoints": 450,
#         "legendaryActionsPerRound": 3,
#         "name_seed_legendaryActionsDescription": "Elder of Gondor, isProper=False",
#         "legendaryActionsDescription": "",
#         "savingThrows": [
#             {
#                 "ability": "strength",
#                 "value": 5,
#                 "proficient": false
#             },
#             {
#                 "ability": "constitution",
#                 "value": 3,
#                 "proficient": false
#             },
#             {
#                 "ability": "wisdom",
#                 "value": 1,
#                 "proficient": false
#             }
#         ],
#         "skills": [
#
#
# [3410 | 5920.44] loss=0.09 avg=0.25
# [3420 | 5936.57] loss=0.15 avg=0.25
# [3430 | 5952.75] loss=0.06 avg=0.25
# [3440 | 5968.96] loss=0.27 avg=0.25
# [3450 | 5985.21] loss=0.08 avg=0.25
# [3460 | 6001.46] loss=0.48 avg=0.25
# [3470 | 6017.67] loss=0.14 avg=0.25
# [3480 | 6033.93] loss=0.08 avg=0.25
# [3490 | 6050.16] loss=0.11 avg=0.25
# [3500 | 6066.37] loss=0.38 avg=0.25
# Saving checkpoint/echidna/model-3500
# [3510 | 6089.31] loss=0.14 avg=0.25
# [3520 | 6105.77] loss=0.50 avg=0.25
# [3530 | 6122.02] loss=0.12 avg=0.25
# [3540 | 6138.20] loss=0.27 avg=0.25
# [3550 | 6154.34] loss=0.08 avg=0.25
# [3560 | 6170.53] loss=0.06 avg=0.24
# [3570 | 6186.78] loss=0.25 avg=0.24
# [3580 | 6203.07] loss=0.16 avg=0.24
# [3590 | 6219.24] loss=0.59 avg=0.25
# [3600 | 6235.42] loss=0.32 avg=0.25
# ======== SAMPLE 1 ========
# Jike's attacks count as magical for overcoming resistance and immunity."
#              },
#              {
#                  "name": "+1 Longsword",
#                  "description": "<i>Melee or Ranged Weapon Attack:</i> +10 to hit, reach 5 ft. or range 20/60 ft., one creature. <i>Hit:</i> 13 with its longsword, or 14 with its longsword if its weapon is longsword length."
#             }
#         ],
#         "name_seed_reactions": "Jike, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Jike, isProper=False",
#         "legendaryActions": [
#             {
#                 "name": "Multiattack",
#                 "description": "The jike makes two hand crossbow attacks."
#             },
#             {
#                 "name": "+1 Crossbowbow, hand"
#             },
#             {
#                 "name": "Pseudopod's Blessing",
#                 "description": "When the jike takes a critical hit, it can deal an additional 10 ft. of damage to one creature with the same roll, using the same attack roll, but without regard to the roll's type. The target must succeed on a DC 13 Dexterity saving throw or have disadvantage on critical hit rolls and ability checks."
#             }
#         ],
#         "hitDieSize": 6
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Jokemaster",
#     "flavor": {
#         "description": "The jock makes two hand crossbow attacks against a frightened creature it can see within 30 feet of it. The target must make a DC 13 Dexterity saving throw or be frightened of joke for 1 minute, during which the joke master can't actually make any attack. The frightened target can repeat its saving throw at the end of each of its turns, ending the effect on itself on a success. To a creature hostile to the joke master, the joker must deal an extra 10 ft. of damage the second time the joke makes an attack."
#        "nameIsProper": false
#     },
#     "stats": {
#        "name_seed_size": "Jokemaster, isProper=False",
#        "size": "Medium",
#        "race": "Human",
#        "alignment": "Any Alignment",
#        "armorType": "Leather",
#        "armorClass": 14,
#        "numHitDie": 7,
#        "speed": "30 ft.",
#        "abilityScores": {
#             "strength": 14,
#             "dexterity": 10,
#             "constitution": 12,
#             "intelligence": 6,
#             "wisdom": 8,
#             "charisma": 6
#        },
#        "proficiencyBonus": 2,
#        "name_seed_damageVulnerabilities": "
#
# [3610 | 6272.35] loss=0.12 avg=0.25
# [3620 | 6288.53] loss=0.63 avg=0.25
# [3630 | 6304.71] loss=0.34 avg=0.25
# [3640 | 6320.92] loss=0.08 avg=0.25
# [3650 | 6337.18] loss=0.31 avg=0.25
# [3660 | 6353.43] loss=0.12 avg=0.25
# [3670 | 6369.68] loss=0.09 avg=0.25
# [3680 | 6385.90] loss=0.32 avg=0.25
# [3690 | 6402.15] loss=0.10 avg=0.25
# [3700 | 6418.34] loss=0.29 avg=0.25
# [3710 | 6434.51] loss=0.09 avg=0.25
# [3720 | 6450.71] loss=0.09 avg=0.24
# [3730 | 6466.90] loss=0.29 avg=0.24
# [3740 | 6483.10] loss=0.55 avg=0.25
# [3750 | 6499.32] loss=0.42 avg=0.25
# [3760 | 6515.53] loss=0.08 avg=0.25
# [3770 | 6531.71] loss=0.11 avg=0.25
# [3780 | 6547.97] loss=0.21 avg=0.25
# [3790 | 6564.19] loss=0.26 avg=0.25
# [3800 | 6580.41] loss=0.53 avg=0.25
# ======== SAMPLE 1 ========
# name_seed_additionalAbilities": "Ginormous Squirrel, isProper=False",
#         "additionalAbilities": [
#             {
#                 "name": "Keen Hearing and Sight",
#                 "description": "the squirrel has advantage on Wisdom (Perception) checks that rely on hearing or sight."
#             },
#             {
#                 "name": "Spider Climb",
#                 "description": "The squirrel can climb difficult surfaces, including upside down on ceilings, without needing to make an ability check."
#             },
#             {
#                 "name": "Web Sense",
#                 "description": "The web snarlcaster has advantage on Perception checks while in contact with a web."
#             },
#             {
#                 "name": "Web Walker",
#                 "description": "the squirrel has advantage on Strength checks to escape from web webs."
#             }
#         ],
#         "name_seed_actions": "Ginormous Squirrel, isProper=False",
#         "actions": [
#             {
#                 "name": "Bite",
#                 "description": "<i>Melee Weapon Attack:</i> +5 to hit, reach 5 ft., one target. <i>Hit:</i> 7 (1d6 + 3) piercing damage."
#             },
#             {
#                 "name": "Web",
#                 "description": "<i>Ranged Weapon Attack:</i> +2 to hit, range 25/50 ft., one target. <i>Hit:</i> 11 (2d6 + 3) bludgeoning damage."
#             }
#         ],
#         "name_seed_reactions": "Ginormous Squirrel, isProper=False",
#         "reactions": [],
#         "name_seed_legendaryActions": "Ginormous Squirrel, isProper=False",
#         "legendaryActions": [],
#         "hitDieSize": 8
#     }
# }
# <-|end|->
# <-|start|->
# {
#     "name": "Ginormous Spinosaurus",
#     "flavor": {
#         "description": "",
#         "nameIsProper": false
#     },
#     "stats": {
#         "name_seed_size": "Ginormous Spinosaurus, isProper=False",
#         "size": "Huge",
#         "race": "beast",
#         "alignment": "Unaligned",
#         "armorType": "",
#         "armorClass": 12,
#         "numHitDie": 12,
#         "speed": "30 ft., swim 10 ft.",
#         "abilityScores": {
#
#
# [3810 | 6617.37] loss=0.27 avg=0.25
# [3820 | 6633.48] loss=0.30 avg=0.25
# [3830 | 6649.69] loss=0.12 avg=0.25
# [3840 | 6665.94] loss=0.12 avg=0.25
# [3850 | 6682.23] loss=0.35 avg=0.25
# [3860 | 6698.43] loss=0.23 avg=0.25
# [3870 | 6714.67] loss=0.19 avg=0.25
# [3880 | 6730.92] loss=0.30 avg=0.25
# [3890 | 6747.16] loss=0.43 avg=0.25
# [3900 | 6763.36] loss=0.09 avg=0.25
# [3910 | 6779.58] loss=0.20 avg=0.25
# [3920 | 6795.81] loss=0.18 avg=0.25
# [3930 | 6812.03] loss=0.43 avg=0.25
# [3940 | 6828.27] loss=0.14 avg=0.25
# [3950 | 6844.46] loss=0.63 avg=0.25
# [3960 | 6860.68] loss=0.39 avg=0.25
# [3970 | 6876.88] loss=0.09 avg=0.25
# [3980 | 6893.08] loss=0.67 avg=0.26
# [3990 | 6909.30] loss=0.99 avg=0.26
# [4000 | 6925.48] loss=0.07 avg=0.26
# Saving checkpoint/echidna/model-4000

# %%
# !ls $root_dir/data
# Out:
# data.json  Experiments	RawBestiaries  TrainingData

# %%
# !ls /content
# Out:
# bin			drive			      models
# checkpoint		gpt_2_simple		      sample_data
# checkpoint_echidna.tar	gpt_2_simple-0.7.2.dist-info  samples
